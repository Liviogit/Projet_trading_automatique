# %%
import yfinance as yf
aapldown=yf.download('AAPL', start='2019-01-01', end='2019-12-31')
aapldown.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2019-01-02  37.667183  37.889009  36.787041  36.944466  148158800
# 2019-01-03  33.915253  34.757230  33.869933  34.342203  365248800
# 2019-01-04  35.363068  35.432241  34.299268  34.473387  234428400
# 2019-01-07  35.284351  35.499022  34.800155  35.468013  219111200
# 2019-01-08  35.956989  36.212208  35.425089  35.673149  164101200

# %%
aapltick=yf.Ticker('AAPL').history(period='1y')
aapltick.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-03-11 00:00:00-04:00  172.127235  173.560470  171.241418  171.938126
# 2024-03-12 00:00:00-04:00  172.336252  173.212122  170.206310  172.415878
# 2024-03-13 00:00:00-04:00  171.958052  172.376076  169.957488  170.325760
# 2024-03-14 00:00:00-04:00  172.097377  173.490792  171.241418  172.186951
# 2024-03-15 00:00:00-04:00  170.365564  171.808746  169.489695  171.808746
#
#                               Volume  Dividends  Stock Splits
# Date
# 2024-03-11 00:00:00-04:00   60139500        0.0           0.0
# 2024-03-12 00:00:00-04:00   59825400        0.0           0.0
# 2024-03-13 00:00:00-04:00   52488700        0.0           0.0
# 2024-03-14 00:00:00-04:00   72913500        0.0           0.0
# 2024-03-15 00:00:00-04:00  121664700        0.0           0.0

# %%
EUROPE = yf.Market("EUROPE")

status = EUROPE.status
summary = EUROPE.summary
summary
# Out:
# {'FGI': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'quoteSourceName': 'Delayed Quote',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'shortName': 'FTSE 100',
#   'marketState': 'REGULAR',
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 15,
#   'exchangeTimezoneName': 'Europe/London',
#   'exchangeTimezoneShortName': 'GMT',
#   'gmtOffSetMilliseconds': 0,
#   'esgPopulated': False,
#   'tradeable': False,
#   'cryptoTradeable': False,
#   'hasPrePostMarketData': False,
#   'firstTradeDateMilliseconds': 441964800000,
#   'priceHint': 2,
#   'regularMarketChange': -9.410156,
#   'regularMarketChangePercent': -0.10941647,
#   'regularMarketTime': 1741688671,
#   'regularMarketPrice': 8590.81,
#   'regularMarketPreviousClose': 8600.22,
#   'exchange': 'FGI',
#   'market': 'gb_market',
#   'fullExchangeName': 'FTSE Index',
#   'symbol': '^FTSE'},
#  'PAR': {'language': 'en-US',
#   'region': 'US',
# ...

# %%
# get list of quotes
quotes = yf.Search("AAPL", max_results=10).quotes

# get list of news
news = yf.Search("Google", news_count=10).news

# get list of related research
research = yf.Search("apple", include_research=True).research

# %%
research
# Out:
# [{'reportHeadline': 'Apple: $500 Billion US Investment Is a Tariff-Avoiding Ploy That We Expect to Succeed',
#   'author': 'William Kerwin',
#   'reportDate': 1740412114000,
#   'id': 'MS_0P000000GY_AnalystReport_1740412114000',
#   'provider': 'Morningstar'},
#  {'reportHeadline': 'Apple: iPhone 16e Meets Our Expectations, and We See C1 Modem as Impressive',
#   'author': 'William Kerwin',
#   'reportDate': 1739995445000,
#   'id': 'MS_0P000000GY_AnalystReport_1739995445000',
#   'provider': 'Morningstar'},
#  {'reportHeadline': 'February Can Be a Tough Month',
#   'reportDate': 1738670405000,
#   'id': 'ARGUS_42563_MarketOutlook_1738670405000',
#   'provider': 'Argus'}]
