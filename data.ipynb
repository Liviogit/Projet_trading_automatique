# %%
import yfinance as yf
aapldown=yf.download('AAPL', start='2019-01-01', end='2019-12-31')
aapldown.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2019-01-02  37.667183  37.889009  36.787041  36.944466  148158800
# 2019-01-03  33.915253  34.757230  33.869933  34.342203  365248800
# 2019-01-04  35.363071  35.432244  34.299271  34.473390  234428400
# 2019-01-07  35.284359  35.499030  34.800162  35.468021  219111200
# 2019-01-08  35.956997  36.212216  35.425097  35.673157  164101200

# %%
aapltick=yf.Ticker('AAPL').history(period='1y')
aapltick.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-03-11 00:00:00-04:00  172.127250  173.560485  171.241434  171.938141
# 2024-03-12 00:00:00-04:00  172.336237  173.212106  170.206295  172.415863
# 2024-03-13 00:00:00-04:00  171.958052  172.376076  169.957488  170.325760
# 2024-03-14 00:00:00-04:00  172.097393  173.490807  171.241434  172.186966
# 2024-03-15 00:00:00-04:00  170.365564  171.808746  169.489695  171.808746
#
#                               Volume  Dividends  Stock Splits
# Date
# 2024-03-11 00:00:00-04:00   60139500        0.0           0.0
# 2024-03-12 00:00:00-04:00   59825400        0.0           0.0
# 2024-03-13 00:00:00-04:00   52488700        0.0           0.0
# 2024-03-14 00:00:00-04:00   72913500        0.0           0.0
# 2024-03-15 00:00:00-04:00  121664700        0.0           0.0

# %%
EUROPE = yf.Market("EUROPE")

status = EUROPE.status
summary = EUROPE.summary
summary
# Out:
# {'FGI': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'quoteSourceName': 'Delayed Quote',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'shortName': 'FTSE 100',
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 15,
#   'exchangeTimezoneName': 'Europe/London',
#   'exchangeTimezoneShortName': 'GMT',
#   'gmtOffSetMilliseconds': 0,
#   'esgPopulated': False,
#   'tradeable': False,
#   'cryptoTradeable': False,
#   'hasPrePostMarketData': False,
#   'firstTradeDateMilliseconds': 441964800000,
#   'priceHint': 2,
#   'regularMarketChange': -14.5,
#   'regularMarketChangePercent': -0.1686017,
#   'regularMarketTime': 1741691087,
#   'regularMarketPrice': 8585.72,
#   'regularMarketPreviousClose': 8600.22,
#   'exchange': 'FGI',
#   'market': 'gb_market',
#   'fullExchangeName': 'FTSE Index',
#   'marketState': 'REGULAR',
#   'symbol': '^FTSE'},
#  'PAR': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'quoteSourceName': 'Delayed Quote',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'shortName': 'Euronext 100 Index',
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 15,
#   'exchangeTimezoneName': 'Europe/Paris',
#   'exchangeTimezoneShortName': 'CET',
#   'gmtOffSetMilliseconds': 3600000,
#   'esgPopulated': False,
#   'tradeable': False,
#   'cryptoTradeable': False,
#   'hasPrePostMarketData': False,
#   'firstTradeDateMilliseconds': 946627200000,
#   'priceHint': 2,
#   'regularMarketChange': 2.5100098,
#   'regularMarketChangePercent': 0.15975723,
#   'regularMarketTime': 1741691085,
#   'regularMarketPrice': 1573.62,
#   'regularMarketPreviousClose': 1571.11,
#   'exchange': 'PAR',
#   'market': 'fr_market',
#   'fullExchangeName': 'Paris',
#   'marketState': 'REGULAR',
#   'symbol': '^N100'},
#  'GER': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'quoteSourceName': 'Delayed Quote',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'shortName': 'DAX                           P',
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 15,
#   'exchangeTimezoneName': 'Europe/Berlin',
#   'exchangeTimezoneShortName': 'CET',
#   'gmtOffSetMilliseconds': 3600000,
#   'esgPopulated': False,
#   'tradeable': False,
#   'cryptoTradeable': False,
#   'hasPrePostMarketData': False,
#   'firstTradeDateMilliseconds': 567849600000,
#   'priceHint': 2,
#   'regularMarketChange': 38.66992,
#   'regularMarketChangePercent': 0.17094173,
#   'regularMarketTime': 1741691087,
#   'regularMarketPrice': 22659.62,
#   'regularMarketPreviousClose': 22620.95,
#   'exchange': 'GER',
#   'market': 'de_market',
#   'fullExchangeName': 'XETRA',
#   'marketState': 'REGULAR',
#   'symbol': '^GDAXI'},
#  'CCY': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'CURRENCY',
#   'typeDisp': 'Currency',
#   'quoteSourceName': 'Delayed Quote',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'currency': 'GBP',
#   'shortName': 'USD/GBP',
#   'regularMarketChange': -0.002579987,
#   'regularMarketChangePercent': -0.33233124,
#   'regularMarketPrice': 0.77391,
#   'regularMarketPreviousClose': 0.77649,
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 0,
#   'exchangeTimezoneName': 'Europe/London',
#   'exchangeTimezoneShortName': 'GMT',
#   'gmtOffSetMilliseconds': 0,
#   'esgPopulated': False,
#   'tradeable': False,
#   'cryptoTradeable': False,
#   'hasPrePostMarketData': False,
#   'firstTradeDateMilliseconds': 1070236800000,
#   'priceHint': 4,
#   'regularMarketTime': 1741691943,
#   'exchange': 'CCY',
#   'market': 'ccy_market',
#   'fullExchangeName': 'CCY',
#   'marketState': 'REGULAR',
#   'symbol': 'GBP=X'}}

# %%
# get list of quotes
quotes = yf.Search("AAPL", max_results=10).news

# get list of news
news = yf.Search("Google", news_count=10).news

# get list of related research
research = yf.Search("apple", include_research=True).research

# %%
quotes
# Out:
# [{'uuid': '4b3ec5c0-5903-302b-8fff-3d2fe3291baa',
#   'title': 'Market Chatter: Apple Set to Redesign iPhone, iPad and Mac Software US This Year',
#   'publisher': 'MT Newswires',
#   'link': 'https://finance.yahoo.com/news/market-chatter-apple-set-redesign-095143601.html',
#   'providerPublishTime': 1741686703,
#   'type': 'STORY',
#   'relatedTickers': ['AAPL']},
#  {'uuid': '739a1c17-2906-38f8-9ccb-25ef0265ae80',
#   'title': 'Tech Stocks to Hit New All-Time Highs in 2025 Despite Early Year Sell-Off, Wedbush Says',
#   'publisher': 'MT Newswires',
#   'link': 'https://finance.yahoo.com/news/tech-stocks-hit-time-highs-101320378.html',
#   'providerPublishTime': 1741688000,
#   'type': 'STORY',
#   'relatedTickers': ['PLTR', 'NVDA', 'AAPL']},
#  {'uuid': '97231e71-43c8-3fce-8523-980b80ed9073',
#   'title': 'Insiders At Apple Sold US$85m In Stock, Alluding To Potential Weakness',
#   'publisher': 'Simply Wall St.',
#   'link': 'https://finance.yahoo.com/news/insiders-apple-sold-us-85m-110025187.html',
#   'providerPublishTime': 1741690825,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/.m1ghW2JIKMrn_021vRckQ--~B/aD00MzI7dz0xMTk0O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/13f69b02f49f819df1dcc276114d4a99',
#      'width': 1194,
#      'height': 432,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/vJzlo.hO4lsED1bc1JFKuA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/13f69b02f49f819df1dcc276114d4a99',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['AAPL']},
#  {'uuid': 'c101636e-fb6a-33c5-977d-93171b7e5cdf',
#   'title': 'Why Apple (AAPL) Shares Are Getting Obliterated Today',
#   'publisher': 'StockStory',
#   'link': 'https://finance.yahoo.com/news/why-apple-aapl-shares-getting-170434628.html',
#   'providerPublishTime': 1741626274,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/CAhBj8O7fJ6i2BC9JUcJ.Q--~B/aD03MDA7dz0xNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/stockstory_922/32591b77a8ad02eacdfd8a45d8896448',
#      'width': 1400,
#      'height': 700,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/zGndBVw9OuqNVc8HxgaD4w--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/stockstory_922/32591b77a8ad02eacdfd8a45d8896448',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['AAPL']},
#  {'uuid': 'fedc9ef5-5819-3a23-a7f7-3889283827db',
#   'title': "Carry trade unwind 'more important than anything,' even tariffs",
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/carry-trade-unwind-more-important-100035801.html',
#   'providerPublishTime': 1741687235,
#   'type': 'VIDEO',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/ndVUq3KKKMD8p1ZjsYHwBw--~B/aD0zMzc4O3c9NjAwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2025-03/8902e7d0-fdbd-11ef-baea-93ca16634a1c',
#      'width': 6000,
#      'height': 3378,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/nYgV5DLGkdYo8HINonXzKw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2025-03/8902e7d0-fdbd-11ef-baea-93ca16634a1c',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^DJI', '^GSPC', '^IXIC']},
#  {'uuid': 'fc43c1c6-3c21-3dac-8908-0fbc111b768c',
#   'title': 'Jim Cramer Highlights Apple (AAPL)’s Edge Over Other AI Companies Amid DeepSeek Saga',
#   'publisher': 'Insider Monkey',
#   'link': 'https://finance.yahoo.com/news/jim-cramer-highlights-apple-aapl-220533646.html',
#   'providerPublishTime': 1741644333,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/fTPNobtT0bdcSxj2xXAamw--~B/aD04MTY7dz0xNDU2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/bd47dc2e86b4a3086f845d200d9daf1f',
#      'width': 1456,
#      'height': 816,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/nIyTyNRglKMNfFFMGli.7A--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/bd47dc2e86b4a3086f845d200d9daf1f',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['AAPL']},
#  {'uuid': '69241c30-cea5-37d5-bf7e-e17646d5b54e',
#   'title': 'Morgan Stanley Pounds the Table on 2 Self-Driving Stocks (That Aren’t Tesla)',
#   'publisher': 'TipRanks',
#   'link': 'https://finance.yahoo.com/news/morgan-stanley-pounds-table-2-103036471.html',
#   'providerPublishTime': 1741689036,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/98Ti1XeD5m44sOGKoLe3xw--~B/aD01NTA7dz0xMDI0O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/tipranks_452/7499cb0f355e426216a61ad7d86e8def',
#      'width': 1024,
#      'height': 550,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/pS.QyGfYskCKYHbLl.K5Dg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/tipranks_452/7499cb0f355e426216a61ad7d86e8def',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['AUR', 'AUROW', 'WRD']},
#  {'uuid': '16340cad-0823-3ef8-85e8-4d3da607a2d2',
#   'title': 'Trump meets Corporate America as economic fears nip stocks',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/trump-meets-corporate-america-economic-100626310.html',
#   'providerPublishTime': 1741687586,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/FIn4dbIWFi2tt.jSqiD9Gg--~B/aD01MzM7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/e18c764479ed32977ffc34e1655821b0',
#      'width': 800,
#      'height': 533,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/odljbTYqEUu2ZCY3ePeLtw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/reuters-finance.com/e18c764479ed32977ffc34e1655821b0',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^GSPC']}]
